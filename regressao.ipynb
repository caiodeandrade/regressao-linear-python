# %% [markdown]
# Importando as bibliotecas utilizadas:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression

# %% [markdown]
# Selecionando as colunas do arquivo .xls e tranformando em arrays:

# %%
df = pd.read_excel("C:\\Users\\Caio\\Faculdade\\analDados\\avContinua\\ipeadata[23-09-2022-03-03].xls")

eixo_x = np.array(list(df.iloc[:, 0])).reshape(-1,1)
eixo_y = np.array(list(df.iloc[:, 1]))

# %% [markdown]
# Criando e plotando o gráfico da regressão linear simples:

# %%
model = LinearRegression().fit(eixo_x,eixo_y)
reta_aproximada = model.predict(eixo_x)


plt.figure(figsize=(10, 5))
plt.scatter(eixo_x, eixo_y, label='Valores observados')
plt.plot(eixo_x, reta_aproximada, label="Valores Esperados")
plt.xlabel('Eixo x')
plt.ylabel('Eixo y')
plt.title("Regressão Linear Simples ")
plt.legend();
